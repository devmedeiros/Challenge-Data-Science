# %% [markdown]
# ## Loading the Dataset

# %% [markdown]
# We start by loading the dataset from the previous week. I'll set the `customerID` as the index column.

# %%
import pandas as pd

start = time.time()

# %%
data = pd.read_csv('../1 - First Week/clean_data.csv', index_col='customerID')
data.head()
# Out:
#            Churn  gender SeniorCitizen Partner Dependents  tenure  \
# customerID
# 0002-ORFBO    No  Female            No     Yes        Yes       9
# 0003-MKNFE    No    Male            No      No         No       9
# 0004-TLHLJ   Yes    Male            No      No         No       4
# 0011-IGKFF   Yes    Male           Yes     Yes         No      13
# 0013-EXCHZ   Yes  Female           Yes     Yes         No       3
#
#            PhoneService MultipleLines InternetService OnlineSecurity  \
# customerID
# 0002-ORFBO          Yes            No             DSL             No
# 0003-MKNFE          Yes           Yes             DSL             No
# 0004-TLHLJ          Yes            No     Fiber optic             No
# 0011-IGKFF          Yes            No     Fiber optic             No
# 0013-EXCHZ          Yes            No     Fiber optic             No
#
#            OnlineBackup DeviceProtection TechSupport StreamingTV  \
# customerID
# 0002-ORFBO          Yes               No         Yes         Yes
# 0003-MKNFE           No               No          No          No
# 0004-TLHLJ           No              Yes          No          No
# 0011-IGKFF          Yes              Yes          No         Yes
# 0013-EXCHZ           No               No         Yes         Yes
#
#            StreamingMovies        Contract PaperlessBilling     PaymentMethod  \
# customerID
# 0002-ORFBO              No        One year              Yes      Mailed check
# 0003-MKNFE             Yes  Month-to-month               No      Mailed check
# 0004-TLHLJ              No  Month-to-month              Yes  Electronic check
# 0011-IGKFF             Yes  Month-to-month              Yes  Electronic check
# 0013-EXCHZ              No  Month-to-month              Yes      Mailed check
#
#             ChargesMonthly  ChargesTotal
# customerID
# 0002-ORFBO            65.6        593.30
# 0003-MKNFE            59.9        542.40
# 0004-TLHLJ            73.9        280.85
# 0011-IGKFF            98.0       1237.85
# 0013-EXCHZ            83.9        267.40

# %% [markdown]
# ## Preparing the dataset

# %%
data = pd.get_dummies(data, drop_first=True)
data.head()
# Out:
#             tenure  ChargesMonthly  ChargesTotal  Churn_Yes  gender_Male  \
# customerID
# 0002-ORFBO       9            65.6        593.30          0            0
# 0003-MKNFE       9            59.9        542.40          0            1
# 0004-TLHLJ       4            73.9        280.85          1            1
# 0011-IGKFF      13            98.0       1237.85          1            1
# 0013-EXCHZ       3            83.9        267.40          1            0
#
#             SeniorCitizen_Yes  Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# customerID
# 0002-ORFBO                  0            1               1                 1
# 0003-MKNFE                  0            0               0                 1
# 0004-TLHLJ                  0            0               0                 1
# 0011-IGKFF                  1            1               0                 1
# 0013-EXCHZ                  1            1               0                 1
#
#             MultipleLines_No phone service  ...  \
# customerID                                  ...
# 0002-ORFBO                               0  ...
# 0003-MKNFE                               0  ...
# 0004-TLHLJ                               0  ...
# 0011-IGKFF                               0  ...
# 0013-EXCHZ                               0  ...
#
#             StreamingTV_No internet service  StreamingTV_Yes  \
# customerID
# 0002-ORFBO                                0                1
# 0003-MKNFE                                0                0
# 0004-TLHLJ                                0                0
# 0011-IGKFF                                0                1
# 0013-EXCHZ                                0                1
#
#             StreamingMovies_No internet service  StreamingMovies_Yes  \
# customerID
# 0002-ORFBO                                    0                    0
# 0003-MKNFE                                    0                    1
# 0004-TLHLJ                                    0                    0
# 0011-IGKFF                                    0                    1
# 0013-EXCHZ                                    0                    0
#
#             Contract_One year  Contract_Two year  PaperlessBilling_Yes  \
# customerID
# 0002-ORFBO                  1                  0                     1
# 0003-MKNFE                  0                  0                     0
# 0004-TLHLJ                  0                  0                     1
# 0011-IGKFF                  0                  0                     1
# 0013-EXCHZ                  0                  0                     1
#
#             PaymentMethod_Credit card (automatic)  \
# customerID
# 0002-ORFBO                                      0
# 0003-MKNFE                                      0
# 0004-TLHLJ                                      0
# 0011-IGKFF                                      0
# 0013-EXCHZ                                      0
#
#             PaymentMethod_Electronic check  PaymentMethod_Mailed check
# customerID
# 0002-ORFBO                               0                           1
# 0003-MKNFE                               0                           1
# 0004-TLHLJ                               1                           0
# 0011-IGKFF                               1                           0
# 0013-EXCHZ                               0                           1
#
# [5 rows x 31 columns]

# %% [markdown]
# Let's look at features correlation, we don't want our features to have a strong correlation among them.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize = (17, 15))

sns.heatmap(data.corr(), annot = True, fmt = ".1f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can see that the `InternetService_No` feature has a lot of strong correlations with many other  features, this is because these other features depend on the client having internet service. So I'll drop all features that are dependent on this one. The same thing happens with `PhoneService_Yes`.
#
# `tenure` and `ChargesTotal` also have a strong correlation, but I'll try running the models with the two features, as I think they are both important.

# %% [markdown]
# I'll normalize `ChargesTotal` and `tenure`.

# %%
import numpy as np

def NormalizeColumn(data, column):
    return (data[column] - np.min(data[column])) / (np.max(data[column]) - np.min(data[column]))

# %%
data.ChargesTotal = NormalizeColumn(data, 'ChargesTotal')
data.tenure = NormalizeColumn(data, 'tenure')

data.head()
# Out:
#               tenure  ChargesMonthly  ChargesTotal  Churn_Yes  gender_Male  \
# customerID
# 0002-ORFBO  0.125000            65.6      0.068315          0            0
# 0003-MKNFE  0.125000            59.9      0.062454          0            1
# 0004-TLHLJ  0.055556            73.9      0.032338          1            1
# 0011-IGKFF  0.180556            98.0      0.142531          1            1
# 0013-EXCHZ  0.041667            83.9      0.030789          1            0
#
#             SeniorCitizen_Yes  Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# customerID
# 0002-ORFBO                  0            1               1                 1
# 0003-MKNFE                  0            0               0                 1
# 0004-TLHLJ                  0            0               0                 1
# 0011-IGKFF                  1            1               0                 1
# 0013-EXCHZ                  1            1               0                 1
#
#             MultipleLines_No phone service  ...  \
# customerID                                  ...
# 0002-ORFBO                               0  ...
# 0003-MKNFE                               0  ...
# 0004-TLHLJ                               0  ...
# 0011-IGKFF                               0  ...
# 0013-EXCHZ                               0  ...
#
#             StreamingTV_No internet service  StreamingTV_Yes  \
# customerID
# 0002-ORFBO                                0                1
# 0003-MKNFE                                0                0
# 0004-TLHLJ                                0                0
# 0011-IGKFF                                0                1
# 0013-EXCHZ                                0                1
#
#             StreamingMovies_No internet service  StreamingMovies_Yes  \
# customerID
# 0002-ORFBO                                    0                    0
# 0003-MKNFE                                    0                    1
# 0004-TLHLJ                                    0                    0
# 0011-IGKFF                                    0                    1
# 0013-EXCHZ                                    0                    0
#
#             Contract_One year  Contract_Two year  PaperlessBilling_Yes  \
# customerID
# 0002-ORFBO                  1                  0                     1
# 0003-MKNFE                  0                  0                     0
# 0004-TLHLJ                  0                  0                     1
# 0011-IGKFF                  0                  0                     1
# 0013-EXCHZ                  0                  0                     1
#
#             PaymentMethod_Credit card (automatic)  \
# customerID
# 0002-ORFBO                                      0
# 0003-MKNFE                                      0
# 0004-TLHLJ                                      0
# 0011-IGKFF                                      0
# 0013-EXCHZ                                      0
#
#             PaymentMethod_Electronic check  PaymentMethod_Mailed check
# customerID
# 0002-ORFBO                               0                           1
# 0003-MKNFE                               0                           1
# 0004-TLHLJ                               1                           0
# 0011-IGKFF                               1                           0
# 0013-EXCHZ                               0                           1
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Splitting into test and train data

# %%
y = data.Churn_Yes
x = data.drop(columns='Churn_Yes')

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=22, stratify=y, shuffle=True)

# %% [markdown]
# ## Baseline Model

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score

# %%
baseline = DummyClassifier(strategy="constant", constant=0)
baseline.fit(x_train, y_train)

y_baseline = baseline.predict(x_test)

baseline_score = accuracy_score(y_test, y_baseline)
print('The Baseline Score is: ', round(baseline_score, 5))
# Out:
# The Baseline Score is:  0.73456

# %% [markdown]
# ## Model 1

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# %%
model1_s = RandomForestClassifier(random_state=22)
parameters = [{
    'criterion': ['gini', 'entropy'],
    'max_depth': [5, 10, 15],
    'max_leaf_nodes': [70, 75, 80]
}]

clf = GridSearchCV(model1_s, param_grid=parameters, cv=5)
clf.fit(x_train, y_train)

print(clf.best_estimator_)
# Out:
# RandomForestClassifier(max_depth=15, max_leaf_nodes=80, random_state=22)

# %%
model1 = RandomForestClassifier(criterion='entropy', max_depth=15, max_leaf_nodes=80, random_state=22)
model1.fit(x_train, y_train)

y_model1 = model1.predict(x_test)

model1_score = accuracy_score(y_test, y_model1)
print('The Model 1 Score is: ', round(model1_score, 5))
# Out:
# The Model 1 Score is:  0.78282

# %% [markdown]
# ## Model 2

# %%
from sklearn.svm import LinearSVC

# %%
model2 = LinearSVC(random_state=22, max_iter=999999)
model2.fit(x_train, y_train)

y_model2 = model2.predict(x_test)

model2_score = accuracy_score(y_test, y_model2)
print('The Model 2 Score is: ', round(model2_score, 5))
# Out:
# The Model 2 Score is:  0.78992

# %% [markdown]
# ## Conclusion

# %%
def incresed_performance(baseline, model):
    return (model-baseline)/baseline

print('Baseline Score {:0.5} \nModel 1 Score  {:0.5} ({:0.2%}) \nModel 2 Score  {:0.5} ({:0.2%})'.\
    format(baseline_score, model1_score, incresed_performance(baseline_score, model1_score),  model2_score, incresed_performance(baseline_score, model2_score)))
# Out:
# Baseline Score 0.73456
# Model 1 Score  0.78282 (6.57%)
# Model 2 Score  0.78992 (7.54%)

# %% [markdown]
# A 7.54% increase in performance over the baseline was the best I could achieve.
